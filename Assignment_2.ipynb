# %%
import numpy as np

#Question 1

array1= np.random.rand(10,1) #Creating an Array with shape (10,1)
print("Mean : ",np.mean(array1)) #Calculating Mean Using Basic Functions Of numpy
# Out:
# Mean :  0.39023872085129124

# %%
#Question 2

array2=np.random.rand(20,1)
print("Standard Deviation : ",np.std(array2)) #Calculating Standard Deviation
print("Variance : ",np.var(array2)) #Calculating Variance
# Out:
# Standard Deviation :  0.35193971257146894
# Variance :  0.12386156128488819

# %%
#Question 3

array3=np.random.rand(10,20)
array4=np.random.rand(20,25)
Matrix = array3.dot(array4) # Matrix multiplication
print(Matrix.shape)
print (Matrix)
print("Sum is : ", np.sum(Matrix))
# Out:
# (10, 25)
# [[4.30125899 5.89834451 6.56803672 5.39074703 5.05007863 3.51979897
#   4.98105382 4.76208424 4.36023073 3.31951063 4.06855541 5.64103159
#   5.11397661 4.13216028 4.90368944 3.96744735 4.18854081 4.28352352
#   3.95674656 4.69740973 3.41238627 4.94090946 5.19831366 5.80394273
#   4.21419473]
#  [4.39326219 4.19761433 6.08401936 4.82490736 4.07584868 2.86112086
#   4.89147182 4.85656414 3.70033602 3.71409427 3.68476673 5.02514607
#   4.81725384 4.13384786 3.79258832 3.36395463 4.5922312  4.00093413
#   4.70204353 3.53494669 2.97810263 4.15446931 5.14629594 5.32431415
#   3.51462731]
#  [4.17678352 4.86957029 6.03635252 4.59628088 4.0814597  2.32969564
#   5.08611955 4.54627172 3.2030154  3.70381602 4.20003712 4.91596817
#   4.86867017 3.96093068 3.53158476 4.28557768 4.76868877 3.73250226
#   3.59763015 4.32000315 3.87514158 3.66890483 4.73812698 4.58860856
#   4.13940625]
#  [5.17577822 6.66302602 6.74519261 5.87504481 5.55836272 4.44847599
# ...

# %%
# Question 4

array4 = np.random.rand(10, 1)
array5=[]
for i in array4:
    i=1/(1 + np.exp(-i))
    array5.append(list(i))
array5
# Out:
# [[0.6951158178382911],
#  [0.6816625237746057],
#  [0.6723616415446326],
#  [0.5249653559111029],
#  [0.664199879762343],
#  [0.69061641927625],
#  [0.5359067032718487],
#  [0.6564455114283002],
#  [0.7200838751066609],
#  [0.611401755548997]]
